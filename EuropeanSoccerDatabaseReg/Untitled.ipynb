# %%
import os
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt

# %%
con = sqlite3.connect('database.sqlite')

# %%
#Select League from database
df = pd.read_sql_query("SELECT * FROM League", con)
plt.rcParams['figure.figsize'] = (20,6)
plt.plot(df["name"], df["id"])

# %%
df2 = pd.read_sql_query("SELECT * FROM Player_Attributes", con)
display(df2.dropna())
# Out:
#             id  player_fifa_api_id  player_api_id                 date  \
# 0            1              218353         505942  2016-02-18 00:00:00
# 1            2              218353         505942  2015-11-19 00:00:00
# 2            3              218353         505942  2015-09-21 00:00:00
# 3            4              218353         505942  2015-03-20 00:00:00
# 4            5              218353         505942  2007-02-22 00:00:00
# ...        ...                 ...            ...                  ...
# 183973  183974              102359          39902  2009-08-30 00:00:00
# 183974  183975              102359          39902  2009-02-22 00:00:00
# 183975  183976              102359          39902  2008-08-30 00:00:00
# 183976  183977              102359          39902  2007-08-30 00:00:00
# 183977  183978              102359          39902  2007-02-22 00:00:00
#
#         overall_rating  potential preferred_foot attacking_work_rate  \
# ...

# %%
df40 = pd.read_sql_query("SELECT * FROM Match", con)
display(df40.dropna())
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 3248    3249        1729       1729  2012/2013      1  2012-08-18 00:00:00
# 3249    3250        1729       1729  2012/2013      1  2012-08-20 00:00:00
# 3250    3251        1729       1729  2012/2013      1  2012-08-18 00:00:00
# 3251    3252        1729       1729  2012/2013      1  2012-08-19 00:00:00
# 3252    3253        1729       1729  2012/2013      1  2012-08-18 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 23412  23413       21518      21518  2012/2013      9  2012-10-28 00:00:00
# 23413  23414       21518      21518  2012/2013      9  2012-10-28 00:00:00
# 23414  23415       21518      21518  2012/2013      9  2012-10-28 00:00:00
# 23415  23416       21518      21518  2012/2013      9  2012-10-27 00:00:00
# 23416  23417       21518      21518  2012/2013      9  2012-10-27 00:00:00
#
# ...

# %%
PlayerMaxPoints = df2[df2.potential == df2.potential.max()]
display(PlayerMaxPoints)
PlayerMaxPoints.id
# Out:
#             id  player_fifa_api_id  player_api_id                 date  \
# 102491  102492              158023          30981  2014-04-25 00:00:00
# 102492  102493              158023          30981  2013-11-15 00:00:00
# 102493  102494              158023          30981  2013-09-20 00:00:00
# 102494  102495              158023          30981  2013-03-22 00:00:00
# 102495  102496              158023          30981  2013-03-08 00:00:00
# 102496  102497              158023          30981  2013-02-15 00:00:00
#
#         overall_rating  potential preferred_foot attacking_work_rate  \
# 102491            94.0       97.0           left              medium
# 102492            94.0       97.0           left                high
# 102493            94.0       97.0           left                high
# 102494            94.0       97.0           left                high
# 102495            94.0       97.0           left                high
# ...

# %%
df4 = pd.read_sql_query("SELECT * FROM Country", con)
display(df4)
df4.to_csv("1.csv", index=False)
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %%
df5 = pd.read_sql_query("SELECT * FROM Country", con)

df5.dropna().to_csv("Country.csv", index=False)

# %%
df6 = pd.read_sql_query("SELECT * FROM League", con)
df6.dropna().to_csv("League.csv", index=False)

# %%
df7 = pd.read_sql_query("SELECT * FROM Match", con)
df7.dropna().to_csv("Match.csv", index=False)

# %%
df8 = pd.read_sql_query("SELECT * FROM Player", con)
df8.dropna().to_csv("Player.csv", index=False)

# %%
df9 = pd.read_sql_query("SELECT * FROM Player_Attributes", con)
df9.dropna().to_csv("Player_Attributes.csv", index=False)

# %%
df10 = pd.read_sql_query("SELECT * FROM Team", con)
df10.dropna().to_csv("Team.csv", index=False)

# %%
df11 = pd.read_sql_query("SELECT * FROM Team_Attributes", con)
df11.dropna().to_csv("Team_Attributes.csv", index=False)

# %%
auxiliar = pd.read_csv("Match.csv")
display(auxiliar)
# Out:
#          id  country_id  league_id     season  stage                 date  \
# 0      3249        1729       1729  2012/2013      1  2012-08-18 00:00:00
# 1      3250        1729       1729  2012/2013      1  2012-08-20 00:00:00
# 2      3251        1729       1729  2012/2013      1  2012-08-18 00:00:00
# 3      3252        1729       1729  2012/2013      1  2012-08-19 00:00:00
# 4      3253        1729       1729  2012/2013      1  2012-08-18 00:00:00
# ...     ...         ...        ...        ...    ...                  ...
# 1757  23413       21518      21518  2012/2013      9  2012-10-28 00:00:00
# 1758  23414       21518      21518  2012/2013      9  2012-10-28 00:00:00
# 1759  23415       21518      21518  2012/2013      9  2012-10-28 00:00:00
# 1760  23416       21518      21518  2012/2013      9  2012-10-27 00:00:00
# 1761  23417       21518      21518  2012/2013      9  2012-10-27 00:00:00
#
#       match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...  \
# ...
